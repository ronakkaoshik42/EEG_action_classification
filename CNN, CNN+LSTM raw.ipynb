# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,BatchNormalization,MaxPooling2D,Reshape, LSTM
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
## Loading the numpy arrays corresponding to the EEG dataset

X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Printing the shapes of the numpy arrays

print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %%
## Adjusting the labels to {0,1,2,3}

# Cue onset left - 0
# Cue onset right - 1
# Cue onset foot - 2
# Cue onset tongue - 3

y_train_valid -= 769
y_test -= 769

# %%
## Creating the training and validation sets

# First generating the training and validation indices using random splitting
ind_valid = np.random.choice(2115, 500, replace=False)
ind_train = np.array(list(set(range(2115)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(x_train, x_valid) = X_train_valid[ind_train], X_train_valid[ind_valid] 
(y_train, y_valid) = y_train_valid[ind_train], y_train_valid[ind_valid]
print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of training set: (1615, 22, 1000)
# Shape of validation set: (500, 22, 1000)
# Shape of training labels: (1615,)
# Shape of validation labels: (500,)
# Shape of training labels after categorical conversion: (1615, 4)
# Shape of validation labels after categorical conversion: (500, 4)
# Shape of test labels after categorical conversion: (443, 4)
# Shape of training set after adding width info: (1615, 22, 1000, 1)
# Shape of validation set after adding width info: (500, 22, 1000, 1)
# Shape of test set after adding width info: (443, 22, 1000, 1)
# Shape of training set after dimension reshaping: (1615, 1000, 1, 22)
# Shape of validation set after dimension reshaping: (500, 1000, 1, 22)
# Shape of test set after dimension reshaping: (443, 1000, 1, 22)

# %% [markdown]
# ## Defining the architecture of a basic CNN model

# %%
# Building the CNN model using sequential class
basic_cnn_model = Sequential()

# Conv. block 1
basic_cnn_model.add(Conv2D(filters=25, kernel_size=(10,1), padding='same', activation='elu', input_shape=(1000,1,22)))
basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
basic_cnn_model.add(BatchNormalization())
basic_cnn_model.add(Dropout(0.5))

# Conv. block 2
basic_cnn_model.add(Conv2D(filters=50, kernel_size=(10,1), padding='same', activation='elu'))
basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
basic_cnn_model.add(BatchNormalization())
basic_cnn_model.add(Dropout(0.5))

# Conv. block 3
basic_cnn_model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu'))
basic_cnn_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
basic_cnn_model.add(BatchNormalization())
basic_cnn_model.add(Dropout(0.5))

# Output layer with Softmax activation
basic_cnn_model.add(Flatten()) # Flattens the input
basic_cnn_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation


# Printing the model summary
basic_cnn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 1000, 1, 25)       5525
#
#  max_pooling2d_6 (MaxPooling  (None, 334, 1, 25)       0
#  2D)
#
#  batch_normalization_6 (Batc  (None, 334, 1, 25)       100
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 334, 1, 25)        0
#
#  conv2d_7 (Conv2D)           (None, 334, 1, 50)        12550
#
#  max_pooling2d_7 (MaxPooling  (None, 112, 1, 50)       0
#  2D)
#
#  batch_normalization_7 (Batc  (None, 112, 1, 50)       200
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 112, 1, 50)        0
#
#  conv2d_8 (Conv2D)           (None, 112, 1, 100)       50100
#
#  max_pooling2d_8 (MaxPooling  (None, 38, 1, 100)       0
#  2D)
#
#  batch_normalization_8 (Batc  (None, 38, 1, 100)       400
#  hNormalization)
#
#  dropout_8 (Dropout)         (None, 38, 1, 100)        0
#
#  flatten_2 (Flatten)         (None, 3800)              0
#
#  dense_2 (Dense)             (None, 4)                 15204
#
# =================================================================
# Total params: 84,079
# Trainable params: 83,729
# Non-trainable params: 350
# _________________________________________________________________

# %% [markdown]
# ## Defining the hyperparameters of the basic CNN model

# %%
# Model parameters
learning_rate = 1.5e-4
epochs = 200
cnn_optimizer = keras.optimizers.Adam(lr=learning_rate)

# %% [markdown]
# ## Compiling, training and validating the basic CNN model

# %%
# Compiling the model
basic_cnn_model.compile(loss='categorical_crossentropy',
                 optimizer=cnn_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
basic_cnn_model_results = basic_cnn_model.fit(x_train,
             y_train,
             batch_size=200,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Epoch 1/200
# 9/9 [==============================] - 7s 684ms/step - loss: 2.3561 - accuracy: 0.2502 - val_loss: 2.6995 - val_accuracy: 0.2700
# Epoch 2/200
# 9/9 [==============================] - 6s 589ms/step - loss: 2.2617 - accuracy: 0.2607 - val_loss: 2.0024 - val_accuracy: 0.2760
# Epoch 3/200
# 9/9 [==============================] - 6s 607ms/step - loss: 2.2615 - accuracy: 0.2737 - val_loss: 1.9629 - val_accuracy: 0.2760
# Epoch 4/200
# 9/9 [==============================] - 6s 618ms/step - loss: 2.1576 - accuracy: 0.2799 - val_loss: 1.7257 - val_accuracy: 0.3000
# Epoch 5/200
# 9/9 [==============================] - 6s 607ms/step - loss: 2.1155 - accuracy: 0.3077 - val_loss: 1.5571 - val_accuracy: 0.3240
# Epoch 6/200
# 9/9 [==============================] - 6s 624ms/step - loss: 2.0642 - accuracy: 0.2985 - val_loss: 1.5417 - val_accuracy: 0.3240
# Epoch 7/200
# 9/9 [==============================] - 5s 599ms/step - loss: 2.0504 - accuracy: 0.2997 - val_loss: 1.5260 - val_accuracy: 0.3400
# Epoch 8/200
# 9/9 [==============================] - 5s 585ms/step - loss: 2.0174 - accuracy: 0.3108 - val_loss: 1.5088 - val_accuracy: 0.3520
# Epoch 9/200
# 9/9 [==============================] - 6s 647ms/step - loss: 1.9581 - accuracy: 0.3325 - val_loss: 1.4855 - val_accuracy: 0.3520
# Epoch 10/200
# 9/9 [==============================] - 6s 740ms/step - loss: 1.9571 - accuracy: 0.3368 - val_loss: 1.4354 - val_accuracy: 0.3600
# Epoch 11/200
# 9/9 [==============================] - 8s 862ms/step - loss: 1.9360 - accuracy: 0.3207 - val_loss: 1.4200 - val_accuracy: 0.3700
# Epoch 12/200
# 9/9 [==============================] - 6s 642ms/step - loss: 1.9055 - accuracy: 0.3331 - val_loss: 1.4037 - val_accuracy: 0.3680
# Epoch 13/200
# 9/9 [==============================] - 6s 628ms/step - loss: 1.9317 - accuracy: 0.3139 - val_loss: 1.4128 - val_accuracy: 0.3620
# Epoch 14/200
# 9/9 [==============================] - 6s 689ms/step - loss: 1.8331 - accuracy: 0.3567 - val_loss: 1.4011 - val_accuracy: 0.3600
# Epoch 15/200
# 9/9 [==============================] - 7s 719ms/step - loss: 1.8424 - accuracy: 0.3653 - val_loss: 1.3967 - val_accuracy: 0.3660
# Epoch 16/200
# 9/9 [==============================] - 5s 565ms/step - loss: 1.8466 - accuracy: 0.3474 - val_loss: 1.3995 - val_accuracy: 0.3660
# Epoch 17/200
# 9/9 [==============================] - 7s 751ms/step - loss: 1.7584 - accuracy: 0.3653 - val_loss: 1.3884 - val_accuracy: 0.3660
# Epoch 18/200
# 9/9 [==============================] - 7s 772ms/step - loss: 1.8472 - accuracy: 0.3412 - val_loss: 1.3816 - val_accuracy: 0.3800
# Epoch 19/200
# 9/9 [==============================] - 7s 760ms/step - loss: 1.9014 - accuracy: 0.3350 - val_loss: 1.3662 - val_accuracy: 0.3600
# Epoch 20/200
# 9/9 [==============================] - 7s 680ms/step - loss: 1.7905 - accuracy: 0.3653 - val_loss: 1.3916 - val_accuracy: 0.3620
# Epoch 21/200
# 9/9 [==============================] - 6s 661ms/step - loss: 1.7961 - accuracy: 0.3666 - val_loss: 1.3793 - val_accuracy: 0.3620
# Epoch 22/200
# 9/9 [==============================] - 5s 589ms/step - loss: 1.7455 - accuracy: 0.3647 - val_loss: 1.3773 - val_accuracy: 0.3560
# Epoch 23/200
# 9/9 [==============================] - 6s 721ms/step - loss: 1.7262 - accuracy: 0.3864 - val_loss: 1.3816 - val_accuracy: 0.3700
# Epoch 24/200
# 9/9 [==============================] - 6s 622ms/step - loss: 1.7807 - accuracy: 0.3585 - val_loss: 1.3974 - val_accuracy: 0.3560
# Epoch 25/200
# 9/9 [==============================] - 6s 709ms/step - loss: 1.7876 - accuracy: 0.3628 - val_loss: 1.4167 - val_accuracy: 0.3520
# Epoch 26/200
# 9/9 [==============================] - 6s 648ms/step - loss: 1.7495 - accuracy: 0.3771 - val_loss: 1.4375 - val_accuracy: 0.3480
# Epoch 27/200
# 9/9 [==============================] - 7s 829ms/step - loss: 1.7424 - accuracy: 0.3746 - val_loss: 1.4287 - val_accuracy: 0.3400
# Epoch 28/200
# 9/9 [==============================] - 6s 649ms/step - loss: 1.7389 - accuracy: 0.3666 - val_loss: 1.4169 - val_accuracy: 0.3540
# Epoch 29/200
# 9/9 [==============================] - 6s 647ms/step - loss: 1.7245 - accuracy: 0.3536 - val_loss: 1.4097 - val_accuracy: 0.3500
# Epoch 30/200
# 9/9 [==============================] - 6s 607ms/step - loss: 1.6702 - accuracy: 0.3926 - val_loss: 1.4414 - val_accuracy: 0.3400
# Epoch 31/200
# 9/9 [==============================] - 7s 729ms/step - loss: 1.6126 - accuracy: 0.4043 - val_loss: 1.4329 - val_accuracy: 0.3500
# Epoch 32/200
# 9/9 [==============================] - 6s 644ms/step - loss: 1.6509 - accuracy: 0.4043 - val_loss: 1.4261 - val_accuracy: 0.3500
# Epoch 33/200
# 9/9 [==============================] - 6s 669ms/step - loss: 1.6217 - accuracy: 0.3963 - val_loss: 1.4566 - val_accuracy: 0.3520
# Epoch 34/200
# 9/9 [==============================] - 6s 695ms/step - loss: 1.5890 - accuracy: 0.4050 - val_loss: 1.4752 - val_accuracy: 0.3320
# Epoch 35/200
# 9/9 [==============================] - 6s 686ms/step - loss: 1.5897 - accuracy: 0.4062 - val_loss: 1.4616 - val_accuracy: 0.3380
# Epoch 36/200
# 9/9 [==============================] - 7s 770ms/step - loss: 1.6227 - accuracy: 0.3975 - val_loss: 1.4219 - val_accuracy: 0.3540
# Epoch 37/200
# 9/9 [==============================] - 7s 773ms/step - loss: 1.5683 - accuracy: 0.4198 - val_loss: 1.4377 - val_accuracy: 0.3440
# Epoch 38/200
# 9/9 [==============================] - 8s 853ms/step - loss: 1.5303 - accuracy: 0.4167 - val_loss: 1.4711 - val_accuracy: 0.3480
# Epoch 39/200
# 9/9 [==============================] - 8s 847ms/step - loss: 1.5746 - accuracy: 0.4180 - val_loss: 1.5199 - val_accuracy: 0.3380
# Epoch 40/200
# 9/9 [==============================] - 7s 748ms/step - loss: 1.5470 - accuracy: 0.4068 - val_loss: 1.4638 - val_accuracy: 0.3600
# Epoch 41/200
# 9/9 [==============================] - 6s 662ms/step - loss: 1.5694 - accuracy: 0.4161 - val_loss: 1.4452 - val_accuracy: 0.3620
# Epoch 42/200
# 9/9 [==============================] - 5s 597ms/step - loss: 1.5249 - accuracy: 0.4365 - val_loss: 1.5055 - val_accuracy: 0.3560
# Epoch 43/200
# 9/9 [==============================] - 5s 599ms/step - loss: 1.5526 - accuracy: 0.4093 - val_loss: 1.4412 - val_accuracy: 0.3640
# Epoch 44/200
# 9/9 [==============================] - 6s 639ms/step - loss: 1.4843 - accuracy: 0.4316 - val_loss: 1.4028 - val_accuracy: 0.3700
# Epoch 45/200
# 9/9 [==============================] - 6s 627ms/step - loss: 1.5169 - accuracy: 0.4279 - val_loss: 1.4546 - val_accuracy: 0.3540
# Epoch 46/200
# 9/9 [==============================] - 6s 643ms/step - loss: 1.4372 - accuracy: 0.4483 - val_loss: 1.4976 - val_accuracy: 0.3600
# Epoch 47/200
# 9/9 [==============================] - 5s 514ms/step - loss: 1.4746 - accuracy: 0.4359 - val_loss: 1.5003 - val_accuracy: 0.3520
# Epoch 48/200
# 9/9 [==============================] - 5s 562ms/step - loss: 1.4484 - accuracy: 0.4656 - val_loss: 1.4835 - val_accuracy: 0.3560
# Epoch 49/200
# 9/9 [==============================] - 5s 601ms/step - loss: 1.4460 - accuracy: 0.4563 - val_loss: 1.4724 - val_accuracy: 0.3600
# Epoch 50/200
# 9/9 [==============================] - 5s 594ms/step - loss: 1.4914 - accuracy: 0.4440 - val_loss: 1.4258 - val_accuracy: 0.3700
# Epoch 51/200
# 9/9 [==============================] - 5s 563ms/step - loss: 1.4152 - accuracy: 0.4551 - val_loss: 1.4350 - val_accuracy: 0.3680
# Epoch 52/200
# 9/9 [==============================] - 5s 540ms/step - loss: 1.4325 - accuracy: 0.4433 - val_loss: 1.4615 - val_accuracy: 0.3700
# Epoch 53/200
# 9/9 [==============================] - 6s 647ms/step - loss: 1.4247 - accuracy: 0.4625 - val_loss: 1.4579 - val_accuracy: 0.3640
# Epoch 54/200
# 9/9 [==============================] - 5s 516ms/step - loss: 1.4731 - accuracy: 0.4495 - val_loss: 1.4437 - val_accuracy: 0.3600
# Epoch 55/200
# 9/9 [==============================] - 5s 548ms/step - loss: 1.4132 - accuracy: 0.4625 - val_loss: 1.4549 - val_accuracy: 0.3640
# Epoch 56/200
# 9/9 [==============================] - 5s 552ms/step - loss: 1.3837 - accuracy: 0.4539 - val_loss: 1.4786 - val_accuracy: 0.3520
# Epoch 57/200
# 9/9 [==============================] - 5s 545ms/step - loss: 1.4087 - accuracy: 0.4755 - val_loss: 1.5026 - val_accuracy: 0.3540
# Epoch 58/200
# 9/9 [==============================] - 5s 526ms/step - loss: 1.3907 - accuracy: 0.4632 - val_loss: 1.4052 - val_accuracy: 0.3900
# Epoch 59/200
# 9/9 [==============================] - 4s 501ms/step - loss: 1.4037 - accuracy: 0.4471 - val_loss: 1.4317 - val_accuracy: 0.3840
# Epoch 60/200
# 9/9 [==============================] - 5s 562ms/step - loss: 1.3933 - accuracy: 0.4539 - val_loss: 1.3943 - val_accuracy: 0.4040
# Epoch 61/200
# 9/9 [==============================] - 5s 523ms/step - loss: 1.4240 - accuracy: 0.4520 - val_loss: 1.3947 - val_accuracy: 0.3860
# Epoch 62/200
# 9/9 [==============================] - 5s 526ms/step - loss: 1.3743 - accuracy: 0.4731 - val_loss: 1.4205 - val_accuracy: 0.3800
# Epoch 63/200
# 9/9 [==============================] - 5s 554ms/step - loss: 1.3379 - accuracy: 0.4867 - val_loss: 1.4555 - val_accuracy: 0.3740
# Epoch 64/200
# 9/9 [==============================] - 5s 556ms/step - loss: 1.4160 - accuracy: 0.4526 - val_loss: 1.4428 - val_accuracy: 0.3640
# Epoch 65/200
# 9/9 [==============================] - 5s 493ms/step - loss: 1.3429 - accuracy: 0.4867 - val_loss: 1.4193 - val_accuracy: 0.3940
# Epoch 66/200
# 9/9 [==============================] - 5s 525ms/step - loss: 1.3549 - accuracy: 0.4768 - val_loss: 1.4543 - val_accuracy: 0.3700
# Epoch 67/200
# 9/9 [==============================] - 5s 523ms/step - loss: 1.3440 - accuracy: 0.4749 - val_loss: 1.4642 - val_accuracy: 0.3780
# Epoch 68/200
# 9/9 [==============================] - 5s 548ms/step - loss: 1.3287 - accuracy: 0.4935 - val_loss: 1.3917 - val_accuracy: 0.3900
# Epoch 69/200
# 9/9 [==============================] - 5s 503ms/step - loss: 1.2956 - accuracy: 0.5040 - val_loss: 1.3703 - val_accuracy: 0.4000
# Epoch 70/200
# 9/9 [==============================] - 6s 633ms/step - loss: 1.2629 - accuracy: 0.5040 - val_loss: 1.3322 - val_accuracy: 0.4260
# Epoch 71/200
# 9/9 [==============================] - 6s 703ms/step - loss: 1.3093 - accuracy: 0.4824 - val_loss: 1.4162 - val_accuracy: 0.3920
# Epoch 72/200
# 9/9 [==============================] - 6s 650ms/step - loss: 1.3050 - accuracy: 0.4960 - val_loss: 1.4446 - val_accuracy: 0.3840
# Epoch 73/200
# 9/9 [==============================] - 6s 637ms/step - loss: 1.3072 - accuracy: 0.4898 - val_loss: 1.4616 - val_accuracy: 0.3900
# Epoch 74/200
# 9/9 [==============================] - 5s 590ms/step - loss: 1.2944 - accuracy: 0.5046 - val_loss: 1.3407 - val_accuracy: 0.4320
# Epoch 75/200
# 9/9 [==============================] - 5s 570ms/step - loss: 1.3266 - accuracy: 0.4811 - val_loss: 1.3564 - val_accuracy: 0.4120
# Epoch 76/200
# 9/9 [==============================] - 5s 551ms/step - loss: 1.2491 - accuracy: 0.5133 - val_loss: 1.3893 - val_accuracy: 0.3940
# Epoch 77/200
# 9/9 [==============================] - 5s 503ms/step - loss: 1.2942 - accuracy: 0.4737 - val_loss: 1.3917 - val_accuracy: 0.3800
# Epoch 78/200
# 9/9 [==============================] - 5s 561ms/step - loss: 1.2647 - accuracy: 0.5195 - val_loss: 1.3503 - val_accuracy: 0.4260
# Epoch 79/200
# 9/9 [==============================] - 4s 482ms/step - loss: 1.2602 - accuracy: 0.5022 - val_loss: 1.3426 - val_accuracy: 0.4360
# Epoch 80/200
# 9/9 [==============================] - 4s 487ms/step - loss: 1.2739 - accuracy: 0.4916 - val_loss: 1.3811 - val_accuracy: 0.4220
# Epoch 81/200
# 9/9 [==============================] - 5s 502ms/step - loss: 1.2330 - accuracy: 0.5238 - val_loss: 1.3855 - val_accuracy: 0.4160
# Epoch 82/200
# 9/9 [==============================] - 5s 593ms/step - loss: 1.2483 - accuracy: 0.5071 - val_loss: 1.3560 - val_accuracy: 0.4380
# Epoch 83/200
# 9/9 [==============================] - 6s 609ms/step - loss: 1.2229 - accuracy: 0.5102 - val_loss: 1.4200 - val_accuracy: 0.4140
# Epoch 84/200
# 9/9 [==============================] - 6s 715ms/step - loss: 1.2507 - accuracy: 0.5096 - val_loss: 1.4687 - val_accuracy: 0.4000
# Epoch 85/200
# 9/9 [==============================] - 6s 624ms/step - loss: 1.1844 - accuracy: 0.5399 - val_loss: 1.4082 - val_accuracy: 0.4180
# Epoch 86/200
# 9/9 [==============================] - 5s 568ms/step - loss: 1.1942 - accuracy: 0.5214 - val_loss: 1.3401 - val_accuracy: 0.4440
# Epoch 87/200
# 9/9 [==============================] - 5s 497ms/step - loss: 1.2232 - accuracy: 0.5214 - val_loss: 1.3519 - val_accuracy: 0.4400
# Epoch 88/200
# 9/9 [==============================] - 7s 734ms/step - loss: 1.2083 - accuracy: 0.5356 - val_loss: 1.3725 - val_accuracy: 0.4240
# Epoch 89/200
# 9/9 [==============================] - 9s 1s/step - loss: 1.2032 - accuracy: 0.5294 - val_loss: 1.3477 - val_accuracy: 0.4340
# Epoch 90/200
# 9/9 [==============================] - 8s 888ms/step - loss: 1.1674 - accuracy: 0.5325 - val_loss: 1.3112 - val_accuracy: 0.4560
# Epoch 91/200
# 9/9 [==============================] - 8s 849ms/step - loss: 1.2309 - accuracy: 0.5356 - val_loss: 1.3585 - val_accuracy: 0.4180
# Epoch 92/200
# 9/9 [==============================] - 8s 887ms/step - loss: 1.1760 - accuracy: 0.5350 - val_loss: 1.3515 - val_accuracy: 0.4280
# Epoch 93/200
# 9/9 [==============================] - 8s 894ms/step - loss: 1.1572 - accuracy: 0.5325 - val_loss: 1.3168 - val_accuracy: 0.4480
# Epoch 94/200
# 9/9 [==============================] - 8s 896ms/step - loss: 1.1746 - accuracy: 0.5430 - val_loss: 1.3181 - val_accuracy: 0.4420
# Epoch 95/200
# 9/9 [==============================] - 8s 867ms/step - loss: 1.1766 - accuracy: 0.5176 - val_loss: 1.3253 - val_accuracy: 0.4420
# Epoch 96/200
# 9/9 [==============================] - 10s 1s/step - loss: 1.1551 - accuracy: 0.5418 - val_loss: 1.3442 - val_accuracy: 0.4480
# Epoch 97/200
# 9/9 [==============================] - 7s 796ms/step - loss: 1.1361 - accuracy: 0.5474 - val_loss: 1.3468 - val_accuracy: 0.4520
# Epoch 98/200
# 9/9 [==============================] - 10s 1s/step - loss: 1.1111 - accuracy: 0.5585 - val_loss: 1.3109 - val_accuracy: 0.4400
# Epoch 99/200
# 9/9 [==============================] - 13s 1s/step - loss: 1.1448 - accuracy: 0.5449 - val_loss: 1.2978 - val_accuracy: 0.4580
# Epoch 100/200
# 9/9 [==============================] - 10s 1s/step - loss: 1.1082 - accuracy: 0.5746 - val_loss: 1.3042 - val_accuracy: 0.4600
# Epoch 101/200
# 9/9 [==============================] - 8s 916ms/step - loss: 1.1236 - accuracy: 0.5486 - val_loss: 1.2346 - val_accuracy: 0.4740
# Epoch 102/200
# 9/9 [==============================] - 8s 826ms/step - loss: 1.1534 - accuracy: 0.5375 - val_loss: 1.2891 - val_accuracy: 0.4560
# Epoch 103/200
# 9/9 [==============================] - 8s 859ms/step - loss: 1.1271 - accuracy: 0.5542 - val_loss: 1.2566 - val_accuracy: 0.4820
# Epoch 104/200
# 9/9 [==============================] - 8s 838ms/step - loss: 1.1464 - accuracy: 0.5486 - val_loss: 1.2647 - val_accuracy: 0.4760
# Epoch 105/200
# 9/9 [==============================] - 8s 859ms/step - loss: 1.0754 - accuracy: 0.5833 - val_loss: 1.2835 - val_accuracy: 0.4660
# Epoch 106/200
# 9/9 [==============================] - 7s 838ms/step - loss: 1.1224 - accuracy: 0.5746 - val_loss: 1.2891 - val_accuracy: 0.4640
# Epoch 107/200
# 9/9 [==============================] - 8s 832ms/step - loss: 1.1141 - accuracy: 0.5505 - val_loss: 1.2682 - val_accuracy: 0.4720
# Epoch 108/200
# 9/9 [==============================] - 8s 849ms/step - loss: 1.0896 - accuracy: 0.5759 - val_loss: 1.2507 - val_accuracy: 0.4840
# Epoch 109/200
# 9/9 [==============================] - 8s 901ms/step - loss: 1.0912 - accuracy: 0.5833 - val_loss: 1.2729 - val_accuracy: 0.4780
# Epoch 110/200
# 9/9 [==============================] - 8s 860ms/step - loss: 1.1174 - accuracy: 0.5548 - val_loss: 1.2679 - val_accuracy: 0.4720
# Epoch 111/200
# 9/9 [==============================] - 8s 840ms/step - loss: 1.0748 - accuracy: 0.5591 - val_loss: 1.2926 - val_accuracy: 0.4580
# Epoch 112/200
# 9/9 [==============================] - 7s 820ms/step - loss: 1.0926 - accuracy: 0.5759 - val_loss: 1.2794 - val_accuracy: 0.4520
# Epoch 113/200
# 9/9 [==============================] - 8s 872ms/step - loss: 1.1100 - accuracy: 0.5622 - val_loss: 1.2578 - val_accuracy: 0.4600
# Epoch 114/200
# 9/9 [==============================] - 8s 841ms/step - loss: 1.0504 - accuracy: 0.5659 - val_loss: 1.3122 - val_accuracy: 0.4500
# Epoch 115/200
# 9/9 [==============================] - 8s 848ms/step - loss: 1.0828 - accuracy: 0.5715 - val_loss: 1.2570 - val_accuracy: 0.4620
# Epoch 116/200
# 9/9 [==============================] - 7s 834ms/step - loss: 1.0645 - accuracy: 0.5616 - val_loss: 1.2130 - val_accuracy: 0.4980
# Epoch 117/200
# 9/9 [==============================] - 8s 842ms/step - loss: 1.0684 - accuracy: 0.5783 - val_loss: 1.2658 - val_accuracy: 0.4780
# Epoch 118/200
# 9/9 [==============================] - 7s 814ms/step - loss: 1.1162 - accuracy: 0.5697 - val_loss: 1.2342 - val_accuracy: 0.4900
# Epoch 119/200
# 9/9 [==============================] - 8s 844ms/step - loss: 1.0588 - accuracy: 0.5808 - val_loss: 1.1913 - val_accuracy: 0.4940
# Epoch 120/200
# 9/9 [==============================] - 7s 821ms/step - loss: 1.0268 - accuracy: 0.5889 - val_loss: 1.2215 - val_accuracy: 0.4720
# Epoch 121/200
# 9/9 [==============================] - 9s 1s/step - loss: 1.0041 - accuracy: 0.5994 - val_loss: 1.2870 - val_accuracy: 0.4600
# Epoch 122/200
# 9/9 [==============================] - 10s 1s/step - loss: 1.0763 - accuracy: 0.5759 - val_loss: 1.2934 - val_accuracy: 0.4620
# Epoch 123/200
# 9/9 [==============================] - 7s 796ms/step - loss: 1.0425 - accuracy: 0.5901 - val_loss: 1.2135 - val_accuracy: 0.4900
# Epoch 124/200
# 9/9 [==============================] - 8s 845ms/step - loss: 1.0464 - accuracy: 0.5814 - val_loss: 1.2418 - val_accuracy: 0.4880
# Epoch 125/200
# 9/9 [==============================] - 7s 796ms/step - loss: 1.0402 - accuracy: 0.5994 - val_loss: 1.2849 - val_accuracy: 0.4660
# Epoch 126/200
# 9/9 [==============================] - 7s 787ms/step - loss: 1.0216 - accuracy: 0.5926 - val_loss: 1.2218 - val_accuracy: 0.4880
# Epoch 127/200
# 9/9 [==============================] - 7s 830ms/step - loss: 1.0453 - accuracy: 0.5950 - val_loss: 1.2042 - val_accuracy: 0.4900
# Epoch 128/200
# 9/9 [==============================] - 8s 866ms/step - loss: 1.0422 - accuracy: 0.5858 - val_loss: 1.2282 - val_accuracy: 0.4860
# Epoch 129/200
# 9/9 [==============================] - 8s 832ms/step - loss: 0.9908 - accuracy: 0.6099 - val_loss: 1.2217 - val_accuracy: 0.4780
# Epoch 130/200
# 9/9 [==============================] - 7s 834ms/step - loss: 1.0009 - accuracy: 0.5994 - val_loss: 1.2037 - val_accuracy: 0.4960
# Epoch 131/200
# 9/9 [==============================] - 11s 1s/step - loss: 1.0078 - accuracy: 0.6031 - val_loss: 1.2514 - val_accuracy: 0.4860
# Epoch 132/200
# 9/9 [==============================] - 8s 843ms/step - loss: 1.0546 - accuracy: 0.5920 - val_loss: 1.2274 - val_accuracy: 0.4820
# Epoch 133/200
# 9/9 [==============================] - 7s 833ms/step - loss: 1.0209 - accuracy: 0.5950 - val_loss: 1.1806 - val_accuracy: 0.4980
# Epoch 134/200
# 9/9 [==============================] - 8s 834ms/step - loss: 0.9928 - accuracy: 0.6192 - val_loss: 1.1916 - val_accuracy: 0.5020
# Epoch 135/200
# 9/9 [==============================] - 8s 832ms/step - loss: 1.0183 - accuracy: 0.6037 - val_loss: 1.2012 - val_accuracy: 0.5000
# Epoch 136/200
# 9/9 [==============================] - 8s 850ms/step - loss: 0.9579 - accuracy: 0.6173 - val_loss: 1.2333 - val_accuracy: 0.4920
# Epoch 137/200
# 9/9 [==============================] - 8s 904ms/step - loss: 0.9694 - accuracy: 0.6130 - val_loss: 1.2326 - val_accuracy: 0.4920
# Epoch 138/200
# 9/9 [==============================] - 8s 860ms/step - loss: 0.9490 - accuracy: 0.6297 - val_loss: 1.1626 - val_accuracy: 0.5140
# Epoch 139/200
# 9/9 [==============================] - 8s 857ms/step - loss: 1.0304 - accuracy: 0.6019 - val_loss: 1.1673 - val_accuracy: 0.5160
# Epoch 140/200
# 9/9 [==============================] - 8s 872ms/step - loss: 1.0013 - accuracy: 0.6000 - val_loss: 1.1764 - val_accuracy: 0.5100
# Epoch 141/200
# 9/9 [==============================] - 8s 848ms/step - loss: 0.9777 - accuracy: 0.6204 - val_loss: 1.2150 - val_accuracy: 0.5020
# Epoch 142/200
# 9/9 [==============================] - 8s 841ms/step - loss: 0.9326 - accuracy: 0.6198 - val_loss: 1.2336 - val_accuracy: 0.4980
# Epoch 143/200
# 9/9 [==============================] - 8s 849ms/step - loss: 0.9991 - accuracy: 0.6111 - val_loss: 1.2415 - val_accuracy: 0.5000
# Epoch 144/200
# 9/9 [==============================] - 8s 866ms/step - loss: 0.9843 - accuracy: 0.6019 - val_loss: 1.1669 - val_accuracy: 0.5300
# Epoch 145/200
# 9/9 [==============================] - 9s 1s/step - loss: 0.9719 - accuracy: 0.6136 - val_loss: 1.1758 - val_accuracy: 0.5280
# Epoch 146/200
# 9/9 [==============================] - 10s 1s/step - loss: 0.9850 - accuracy: 0.6167 - val_loss: 1.1558 - val_accuracy: 0.5300
# Epoch 147/200
# 9/9 [==============================] - 10s 1s/step - loss: 0.9348 - accuracy: 0.6254 - val_loss: 1.1734 - val_accuracy: 0.5280
# Epoch 148/200
# 9/9 [==============================] - 12s 1s/step - loss: 0.9506 - accuracy: 0.6180 - val_loss: 1.1587 - val_accuracy: 0.5260
# Epoch 149/200
# 9/9 [==============================] - 9s 918ms/step - loss: 0.9523 - accuracy: 0.6192 - val_loss: 1.1393 - val_accuracy: 0.5220
# Epoch 150/200
# 9/9 [==============================] - 8s 851ms/step - loss: 0.8994 - accuracy: 0.6427 - val_loss: 1.1484 - val_accuracy: 0.5180
# Epoch 151/200
# 9/9 [==============================] - 8s 861ms/step - loss: 0.9368 - accuracy: 0.6322 - val_loss: 1.1431 - val_accuracy: 0.5300
# Epoch 152/200
# 9/9 [==============================] - 8s 828ms/step - loss: 0.9505 - accuracy: 0.6037 - val_loss: 1.1404 - val_accuracy: 0.5240
# Epoch 153/200
# 9/9 [==============================] - 8s 864ms/step - loss: 0.9326 - accuracy: 0.6390 - val_loss: 1.1592 - val_accuracy: 0.5300
# Epoch 154/200
# 9/9 [==============================] - 8s 851ms/step - loss: 0.9258 - accuracy: 0.6272 - val_loss: 1.2244 - val_accuracy: 0.5020
# Epoch 155/200
# 9/9 [==============================] - 9s 1s/step - loss: 0.9207 - accuracy: 0.6359 - val_loss: 1.1546 - val_accuracy: 0.5340
# Epoch 156/200
# 9/9 [==============================] - 8s 868ms/step - loss: 0.9621 - accuracy: 0.6149 - val_loss: 1.1397 - val_accuracy: 0.5220
# Epoch 157/200
# 9/9 [==============================] - 8s 879ms/step - loss: 0.9505 - accuracy: 0.6353 - val_loss: 1.1992 - val_accuracy: 0.5140
# Epoch 158/200
# 9/9 [==============================] - 8s 874ms/step - loss: 0.8913 - accuracy: 0.6495 - val_loss: 1.1728 - val_accuracy: 0.5220
# Epoch 159/200
# 9/9 [==============================] - 8s 915ms/step - loss: 0.9128 - accuracy: 0.6402 - val_loss: 1.1651 - val_accuracy: 0.5300
# Epoch 160/200
# 9/9 [==============================] - 8s 847ms/step - loss: 0.9429 - accuracy: 0.6341 - val_loss: 1.1839 - val_accuracy: 0.5200
# Epoch 161/200
# 9/9 [==============================] - 8s 875ms/step - loss: 0.9347 - accuracy: 0.6334 - val_loss: 1.1758 - val_accuracy: 0.5300
# Epoch 162/200
# 9/9 [==============================] - 8s 870ms/step - loss: 0.9458 - accuracy: 0.6421 - val_loss: 1.1256 - val_accuracy: 0.5380
# Epoch 163/200
# 9/9 [==============================] - 8s 850ms/step - loss: 0.8989 - accuracy: 0.6415 - val_loss: 1.1468 - val_accuracy: 0.5260
# Epoch 164/200
# 9/9 [==============================] - 8s 857ms/step - loss: 0.8999 - accuracy: 0.6446 - val_loss: 1.2016 - val_accuracy: 0.5080
# Epoch 165/200
# 9/9 [==============================] - 8s 941ms/step - loss: 0.8767 - accuracy: 0.6440 - val_loss: 1.1842 - val_accuracy: 0.5180
# Epoch 166/200
# 9/9 [==============================] - 8s 896ms/step - loss: 0.8641 - accuracy: 0.6638 - val_loss: 1.1478 - val_accuracy: 0.5280
# Epoch 167/200
# 9/9 [==============================] - 8s 904ms/step - loss: 0.8714 - accuracy: 0.6477 - val_loss: 1.1171 - val_accuracy: 0.5400
# Epoch 168/200
# 9/9 [==============================] - 8s 914ms/step - loss: 0.9080 - accuracy: 0.6594 - val_loss: 1.0992 - val_accuracy: 0.5460
# Epoch 169/200
# 9/9 [==============================] - 10s 1s/step - loss: 0.9023 - accuracy: 0.6440 - val_loss: 1.1180 - val_accuracy: 0.5360
# Epoch 170/200
# 9/9 [==============================] - 10s 1s/step - loss: 0.8787 - accuracy: 0.6427 - val_loss: 1.1247 - val_accuracy: 0.5300
# Epoch 171/200
# 9/9 [==============================] - 10s 1s/step - loss: 0.8761 - accuracy: 0.6539 - val_loss: 1.1391 - val_accuracy: 0.5220
# Epoch 172/200
# 9/9 [==============================] - 10s 1s/step - loss: 0.8817 - accuracy: 0.6427 - val_loss: 1.1838 - val_accuracy: 0.5220
# Epoch 173/200
# 9/9 [==============================] - 9s 952ms/step - loss: 0.8703 - accuracy: 0.6656 - val_loss: 1.1482 - val_accuracy: 0.5400
# Epoch 174/200
# 9/9 [==============================] - 8s 838ms/step - loss: 0.8849 - accuracy: 0.6458 - val_loss: 1.1284 - val_accuracy: 0.5440
# Epoch 175/200
# 9/9 [==============================] - 8s 854ms/step - loss: 0.8855 - accuracy: 0.6384 - val_loss: 1.1262 - val_accuracy: 0.5380
# Epoch 176/200
# 9/9 [==============================] - 8s 855ms/step - loss: 0.8834 - accuracy: 0.6353 - val_loss: 1.1551 - val_accuracy: 0.5240
# Epoch 177/200
# 9/9 [==============================] - 7s 826ms/step - loss: 0.8754 - accuracy: 0.6489 - val_loss: 1.1230 - val_accuracy: 0.5340
# Epoch 178/200
# 9/9 [==============================] - 8s 836ms/step - loss: 0.8480 - accuracy: 0.6718 - val_loss: 1.0968 - val_accuracy: 0.5460
# Epoch 179/200
# 9/9 [==============================] - 8s 850ms/step - loss: 0.8731 - accuracy: 0.6539 - val_loss: 1.0897 - val_accuracy: 0.5460
# Epoch 180/200
# 9/9 [==============================] - 8s 855ms/step - loss: 0.8527 - accuracy: 0.6520 - val_loss: 1.1277 - val_accuracy: 0.5520
# Epoch 181/200
# 9/9 [==============================] - 8s 835ms/step - loss: 0.8599 - accuracy: 0.6495 - val_loss: 1.1280 - val_accuracy: 0.5260
# Epoch 182/200
# 9/9 [==============================] - 8s 855ms/step - loss: 0.8791 - accuracy: 0.6582 - val_loss: 1.1592 - val_accuracy: 0.5220
# Epoch 183/200
# 9/9 [==============================] - 8s 875ms/step - loss: 0.8717 - accuracy: 0.6483 - val_loss: 1.1440 - val_accuracy: 0.5300
# Epoch 184/200
# 9/9 [==============================] - 8s 852ms/step - loss: 0.8586 - accuracy: 0.6601 - val_loss: 1.1195 - val_accuracy: 0.5360
# Epoch 185/200
# 9/9 [==============================] - 8s 891ms/step - loss: 0.8624 - accuracy: 0.6594 - val_loss: 1.1553 - val_accuracy: 0.5320
# Epoch 186/200
# 9/9 [==============================] - 8s 864ms/step - loss: 0.8608 - accuracy: 0.6693 - val_loss: 1.1326 - val_accuracy: 0.5380
# Epoch 187/200
# 9/9 [==============================] - 8s 924ms/step - loss: 0.8642 - accuracy: 0.6483 - val_loss: 1.1104 - val_accuracy: 0.5580
# Epoch 188/200
# 9/9 [==============================] - 7s 837ms/step - loss: 0.8636 - accuracy: 0.6489 - val_loss: 1.1138 - val_accuracy: 0.5520
# Epoch 189/200
# 9/9 [==============================] - 8s 894ms/step - loss: 0.8606 - accuracy: 0.6520 - val_loss: 1.1448 - val_accuracy: 0.5340
# Epoch 190/200
# 9/9 [==============================] - 8s 870ms/step - loss: 0.8263 - accuracy: 0.6768 - val_loss: 1.1756 - val_accuracy: 0.5220
# Epoch 191/200
# 9/9 [==============================] - 10s 1s/step - loss: 0.8169 - accuracy: 0.6923 - val_loss: 1.1167 - val_accuracy: 0.5480
# Epoch 192/200
# 9/9 [==============================] - 8s 895ms/step - loss: 0.8631 - accuracy: 0.6477 - val_loss: 1.0833 - val_accuracy: 0.5580
# Epoch 193/200
# 9/9 [==============================] - 9s 1s/step - loss: 0.8501 - accuracy: 0.6644 - val_loss: 1.0788 - val_accuracy: 0.5660
# Epoch 194/200
# 9/9 [==============================] - 9s 1s/step - loss: 0.8621 - accuracy: 0.6687 - val_loss: 1.1322 - val_accuracy: 0.5380
# Epoch 195/200
# 9/9 [==============================] - 8s 895ms/step - loss: 0.8611 - accuracy: 0.6706 - val_loss: 1.1693 - val_accuracy: 0.5340
# Epoch 196/200
# 9/9 [==============================] - 8s 849ms/step - loss: 0.8257 - accuracy: 0.6817 - val_loss: 1.1383 - val_accuracy: 0.5420
# Epoch 197/200
# 9/9 [==============================] - 7s 830ms/step - loss: 0.8213 - accuracy: 0.6799 - val_loss: 1.1511 - val_accuracy: 0.5320
# Epoch 198/200
# 9/9 [==============================] - 8s 858ms/step - loss: 0.8108 - accuracy: 0.6774 - val_loss: 1.1357 - val_accuracy: 0.5280
# Epoch 199/200
# 9/9 [==============================] - 8s 835ms/step - loss: 0.8341 - accuracy: 0.6718 - val_loss: 1.1377 - val_accuracy: 0.5360
# Epoch 200/200
# 9/9 [==============================] - 7s 817ms/step - loss: 0.8143 - accuracy: 0.6693 - val_loss: 1.1216 - val_accuracy: 0.5380

# %% [markdown]
# ## (CNN) Visualizing the accuracy and loss trajectory

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(basic_cnn_model_results.history['accuracy'])
plt.plot(basic_cnn_model_results.history['val_accuracy'])
plt.title('Basic CNN model accuracy trajectory w/o pre-processing')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(basic_cnn_model_results.history['loss'],'o')
plt.plot(basic_cnn_model_results.history['val_loss'],'o')
plt.title('Basic CNN model loss trajectory w/o pre-processing')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## (CNN) Testing the performance of the basic CNN model on the held out test set

# %%
## Testing the basic CNN model
cnn_score = basic_cnn_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the basic CNN model:',cnn_score[1])
# Out:
# Test accuracy of the basic CNN model: 0.5575620532035828

# %% [markdown]
# ## Defining the architecture of a basic CNN+LSTM model

# %%
# Building the CNN model using sequential class
hybrid_cnn_lstm_model = Sequential()

# Conv. block 1
hybrid_cnn_lstm_model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu', input_shape=(1000,1,22)))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same')) # Read the keras documentation
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.5))

# Conv. block 2
hybrid_cnn_lstm_model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.5))

# Conv. block 3
hybrid_cnn_lstm_model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu'))
hybrid_cnn_lstm_model.add(MaxPooling2D(pool_size=(3,1), padding='same'))
hybrid_cnn_lstm_model.add(BatchNormalization())
hybrid_cnn_lstm_model.add(Dropout(0.5))


# FC+LSTM layers
hybrid_cnn_lstm_model.add(Flatten()) # Adding a flattening operation to the output of CNN block
hybrid_cnn_lstm_model.add(Dense((100))) # FC layer with 100 units
hybrid_cnn_lstm_model.add(Reshape((100,1))) # Reshape my output of FC layer so that it's compatible
hybrid_cnn_lstm_model.add(LSTM(100, dropout=0.6, recurrent_dropout=0.1, input_shape=(100,1), return_sequences=True))

hybrid_cnn_lstm_model.add(LSTM(70, dropout=0.6, recurrent_dropout=0.1, return_sequences=False))
# Output layer with Softmax activation 
hybrid_cnn_lstm_model.add(Dense(4, activation='softmax')) # Output FC layer with softmax activation


# Printing the model summary
hybrid_cnn_lstm_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_18 (Conv2D)          (None, 1000, 1, 100)      22100
#
#  max_pooling2d_18 (MaxPoolin  (None, 334, 1, 100)      0
#  g2D)
#
#  batch_normalization_18 (Bat  (None, 334, 1, 100)      400
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 334, 1, 100)       0
#
#  conv2d_19 (Conv2D)          (None, 334, 1, 100)       100100
#
#  max_pooling2d_19 (MaxPoolin  (None, 112, 1, 100)      0
#  g2D)
#
#  batch_normalization_19 (Bat  (None, 112, 1, 100)      400
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 112, 1, 100)       0
#
#  conv2d_20 (Conv2D)          (None, 112, 1, 100)       100100
#
#  max_pooling2d_20 (MaxPoolin  (None, 38, 1, 100)       0
#  g2D)
#
#  batch_normalization_20 (Bat  (None, 38, 1, 100)       400
#  chNormalization)
#
#  dropout_20 (Dropout)        (None, 38, 1, 100)        0
#
#  flatten_6 (Flatten)         (None, 3800)              0
#
#  dense_7 (Dense)             (None, 100)               380100
#
#  reshape_3 (Reshape)         (None, 100, 1)            0
#
#  lstm_2 (LSTM)               (None, 100, 100)          40800
#
#  lstm_3 (LSTM)               (None, 70)                47880
#
#  dense_8 (Dense)             (None, 4)                 284
#
# =================================================================
# Total params: 692,564
# Trainable params: 691,964
# Non-trainable params: 600
# _________________________________________________________________

# %% [markdown]
# ## Defining the hyperparameters of the basic CNN model

# %%
# Model parameters
learning_rate = 2e-3
epochs = 50
hybrid_cnn_lstm_optimizer = keras.optimizers.Adam(lr=learning_rate)

# %%
hybrid_cnn_lstm_model.compile(loss='categorical_crossentropy',
                 optimizer=hybrid_cnn_lstm_optimizer,
                 metrics=['accuracy'])

# Training and validating the model
hybrid_cnn_lstm_model_results = hybrid_cnn_lstm_model.fit(x_train,
             y_train,
             batch_size=200,
             epochs=epochs,
             validation_data=(x_valid, y_valid), verbose=True)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 60s 4s/step - loss: 1.3832 - accuracy: 0.2663 - val_loss: 1.6038 - val_accuracy: 0.2520
# Epoch 2/50
# 9/9 [==============================] - 32s 4s/step - loss: 1.3518 - accuracy: 0.3158 - val_loss: 1.7350 - val_accuracy: 0.2640
# Epoch 3/50
# 9/9 [==============================] - 33s 4s/step - loss: 1.3244 - accuracy: 0.3437 - val_loss: 1.5477 - val_accuracy: 0.3080
# Epoch 4/50
# 9/9 [==============================] - 30s 3s/step - loss: 1.3054 - accuracy: 0.3789 - val_loss: 1.6270 - val_accuracy: 0.3100
# Epoch 5/50
# 9/9 [==============================] - 30s 3s/step - loss: 1.2642 - accuracy: 0.4099 - val_loss: 1.5202 - val_accuracy: 0.3520
# Epoch 6/50
# 9/9 [==============================] - 30s 3s/step - loss: 1.2419 - accuracy: 0.4396 - val_loss: 1.4883 - val_accuracy: 0.3920
# Epoch 7/50
# 9/9 [==============================] - 31s 3s/step - loss: 1.2341 - accuracy: 0.4180 - val_loss: 1.5045 - val_accuracy: 0.3740
# Epoch 8/50
# 9/9 [==============================] - 36s 4s/step - loss: 1.1996 - accuracy: 0.4477 - val_loss: 1.4288 - val_accuracy: 0.4500
# Epoch 9/50
# 9/9 [==============================] - 36s 4s/step - loss: 1.1826 - accuracy: 0.4749 - val_loss: 1.8149 - val_accuracy: 0.3920
# Epoch 10/50
# 9/9 [==============================] - 34s 4s/step - loss: 1.1259 - accuracy: 0.4972 - val_loss: 1.4092 - val_accuracy: 0.4280
# Epoch 11/50
# 9/9 [==============================] - 32s 4s/step - loss: 1.0951 - accuracy: 0.5046 - val_loss: 1.6444 - val_accuracy: 0.4060
# Epoch 12/50
# 9/9 [==============================] - 33s 4s/step - loss: 1.0701 - accuracy: 0.5251 - val_loss: 1.4243 - val_accuracy: 0.4300
# Epoch 13/50
# 9/9 [==============================] - 32s 4s/step - loss: 1.0695 - accuracy: 0.5207 - val_loss: 1.6371 - val_accuracy: 0.4060
# Epoch 14/50
# 9/9 [==============================] - 34s 4s/step - loss: 1.0701 - accuracy: 0.5115 - val_loss: 1.4932 - val_accuracy: 0.4440
# Epoch 15/50
# 9/9 [==============================] - 34s 4s/step - loss: 1.0724 - accuracy: 0.5251 - val_loss: 1.7326 - val_accuracy: 0.4200
# Epoch 16/50
# 9/9 [==============================] - 33s 4s/step - loss: 1.0454 - accuracy: 0.5399 - val_loss: 1.4836 - val_accuracy: 0.4380
# Epoch 17/50
# 9/9 [==============================] - 32s 3s/step - loss: 1.0369 - accuracy: 0.5350 - val_loss: 1.3387 - val_accuracy: 0.4480
# Epoch 18/50
# 9/9 [==============================] - 30s 3s/step - loss: 1.0039 - accuracy: 0.5598 - val_loss: 1.3753 - val_accuracy: 0.4580
# Epoch 19/50
# 9/9 [==============================] - 31s 3s/step - loss: 0.9876 - accuracy: 0.5740 - val_loss: 1.2983 - val_accuracy: 0.4580
# Epoch 20/50
# 9/9 [==============================] - 30s 3s/step - loss: 0.9881 - accuracy: 0.5610 - val_loss: 1.4440 - val_accuracy: 0.4620
# Epoch 21/50
# 9/9 [==============================] - 32s 4s/step - loss: 0.9593 - accuracy: 0.5851 - val_loss: 1.7397 - val_accuracy: 0.4460
# Epoch 22/50
# 9/9 [==============================] - 30s 3s/step - loss: 0.9734 - accuracy: 0.5882 - val_loss: 1.5124 - val_accuracy: 0.4620
# Epoch 23/50
# 9/9 [==============================] - 32s 4s/step - loss: 0.9300 - accuracy: 0.6006 - val_loss: 1.5455 - val_accuracy: 0.4780
# Epoch 24/50
# 9/9 [==============================] - 31s 3s/step - loss: 0.9095 - accuracy: 0.6173 - val_loss: 1.5943 - val_accuracy: 0.4500
# Epoch 25/50
# 9/9 [==============================] - 30s 3s/step - loss: 0.9018 - accuracy: 0.6155 - val_loss: 1.5745 - val_accuracy: 0.4440
# Epoch 26/50
# 9/9 [==============================] - 32s 4s/step - loss: 0.8657 - accuracy: 0.6347 - val_loss: 1.6370 - val_accuracy: 0.4520
# Epoch 27/50
# 9/9 [==============================] - 31s 3s/step - loss: 0.9295 - accuracy: 0.6186 - val_loss: 1.4864 - val_accuracy: 0.4360
# Epoch 28/50
# 9/9 [==============================] - 30s 3s/step - loss: 0.8871 - accuracy: 0.6396 - val_loss: 1.5279 - val_accuracy: 0.4260
# Epoch 29/50
# 9/9 [==============================] - 31s 3s/step - loss: 0.8662 - accuracy: 0.6415 - val_loss: 1.5679 - val_accuracy: 0.4520
# Epoch 30/50
# 9/9 [==============================] - 35s 4s/step - loss: 0.8690 - accuracy: 0.6495 - val_loss: 1.4755 - val_accuracy: 0.4320
# Epoch 31/50
# 9/9 [==============================] - 54s 6s/step - loss: 0.8053 - accuracy: 0.6718 - val_loss: 1.5722 - val_accuracy: 0.4620
# Epoch 32/50
# 9/9 [==============================] - 48s 4s/step - loss: 0.7806 - accuracy: 0.6892 - val_loss: 1.5180 - val_accuracy: 0.4800
# Epoch 33/50
# 9/9 [==============================] - 31s 3s/step - loss: 0.7865 - accuracy: 0.6799 - val_loss: 1.4379 - val_accuracy: 0.4920
# Epoch 34/50
# 9/9 [==============================] - 29s 3s/step - loss: 0.7789 - accuracy: 0.6935 - val_loss: 1.5636 - val_accuracy: 0.4820
# Epoch 35/50
# 9/9 [==============================] - 36s 4s/step - loss: 0.7112 - accuracy: 0.7220 - val_loss: 1.7321 - val_accuracy: 0.4680
# Epoch 36/50
# 9/9 [==============================] - 32s 3s/step - loss: 0.7065 - accuracy: 0.7065 - val_loss: 1.7071 - val_accuracy: 0.4540
# Epoch 37/50
# 9/9 [==============================] - 31s 4s/step - loss: 0.7139 - accuracy: 0.7201 - val_loss: 1.6352 - val_accuracy: 0.4700
# Epoch 38/50
# 9/9 [==============================] - 31s 3s/step - loss: 0.7335 - accuracy: 0.7238 - val_loss: 1.6307 - val_accuracy: 0.4840
# Epoch 39/50
# 9/9 [==============================] - 35s 4s/step - loss: 0.6851 - accuracy: 0.7257 - val_loss: 1.6089 - val_accuracy: 0.5000
# Epoch 40/50
# 9/9 [==============================] - 30s 3s/step - loss: 0.6855 - accuracy: 0.7263 - val_loss: 1.6638 - val_accuracy: 0.4860
# Epoch 41/50
# 9/9 [==============================] - 31s 4s/step - loss: 0.6859 - accuracy: 0.7288 - val_loss: 1.8658 - val_accuracy: 0.4440
# Epoch 42/50
# 9/9 [==============================] - 30s 3s/step - loss: 0.6724 - accuracy: 0.7331 - val_loss: 1.6601 - val_accuracy: 0.4860
# Epoch 43/50
# 9/9 [==============================] - 30s 3s/step - loss: 0.6246 - accuracy: 0.7548 - val_loss: 1.7559 - val_accuracy: 0.4720
# Epoch 44/50
# 9/9 [==============================] - 29s 3s/step - loss: 0.6449 - accuracy: 0.7461 - val_loss: 1.7442 - val_accuracy: 0.4780
# Epoch 45/50
# 9/9 [==============================] - 34s 4s/step - loss: 0.6160 - accuracy: 0.7833 - val_loss: 1.6906 - val_accuracy: 0.5000
# Epoch 46/50
# 9/9 [==============================] - 34s 4s/step - loss: 0.5471 - accuracy: 0.8012 - val_loss: 1.7012 - val_accuracy: 0.5080
# Epoch 47/50
# 9/9 [==============================] - 29s 3s/step - loss: 0.5889 - accuracy: 0.7839 - val_loss: 1.7746 - val_accuracy: 0.4960
# Epoch 48/50
# 9/9 [==============================] - 28s 3s/step - loss: 0.6067 - accuracy: 0.7777 - val_loss: 1.8299 - val_accuracy: 0.4900
# Epoch 49/50
# 9/9 [==============================] - 28s 3s/step - loss: 0.5698 - accuracy: 0.7920 - val_loss: 1.8356 - val_accuracy: 0.4700
# Epoch 50/50
# 9/9 [==============================] - 27s 3s/step - loss: 0.5606 - accuracy: 0.7870 - val_loss: 1.8349 - val_accuracy: 0.4860

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['accuracy'])
plt.plot(hybrid_cnn_lstm_model_results.history['val_accuracy'])
plt.title('Hybrid CNN-LSTM model accuracy trajectory w/o pre-processing')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(hybrid_cnn_lstm_model_results.history['loss'],'o')
plt.plot(hybrid_cnn_lstm_model_results.history['val_loss'],'o')
plt.title('Hybrid CNN-LSTM model loss trajectory w/o pre-processing')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the hybrid CNN-LSTM model

hybrid_cnn_lstm_score = hybrid_cnn_lstm_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the hybrid CNN-LSTM model:',hybrid_cnn_lstm_score[1])
# Out:
# Test accuracy of the hybrid CNN-LSTM model: 0.4898419976234436
